# %%
# Pyber Challenge

# %%
### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %%
### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])


# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city           date   fare       ride_id  driver_count   type
# 0  Lake Jonathanshire  1/14/19 10:14  13.83  5.739410e+12             5  Urban
# 1  South Michelleport   3/4/19 18:24  30.24  2.343910e+12            72  Urban
# 2  Port Samanthamouth   2/24/19 4:29  33.44  2.005070e+12            57  Urban
# 3          Rodneyfort  2/10/19 23:22  23.44  5.149250e+12            34  Urban
# 4          South Jack    3/6/19 4:28  34.58  3.908450e+12            46  Urban

# %%
## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type

urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]

urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]

urban_ride_count.head()
# Out:
# city
# Amandaburgh        18
# Barajasview        22
# Carriemouth        27
# Christopherfurt    27
# Deanville          19
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type

urban_driver_total = urban_cities_df.groupby(["city"]).sum()["driver_count"]
suburban_driver_total = suburban_cities_df.groupby(["city"]).sum()["driver_count"]
rural_driver_total = rural_cities_df.groupby(["city"]).sum()["driver_count"]

urban_driver_total.head()
# Out:
# city
# Amandaburgh         216
# Barajasview         572
# Carriemouth        1404
# Christopherfurt    1107
# Deanville           931
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type

urban_driver_total_fare = urban_cities_df.groupby(["city"]).sum()["fare"]
suburban_driver_total_fare = suburban_cities_df.groupby(["city"]).sum()["fare"]
rural_driver_total_fare = rural_cities_df.groupby(["city"]).sum()["fare"]

rural_driver_total_fare.head()
# Out:
# city
# Bradshawfurt      400.64
# Garzaport          72.37
# Harringtonfort    200.82
# Jessicaport       216.08
# Lake Jamie        206.15
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
urban_ride_total = urban_cities_df.groupby(["city"]).sum()["ride_id"]
rural_ride_total = rural_cities_df.groupby(["city"]).sum()["ride_id"]
suburban_ride_total = suburban_cities_df.groupby(["city"]).sum()["ride_id"]

urban_ride_total_fare = urban_cities_df.groupby(["city"]).sum()["fare"]
rural_ride_total_fare = rural_cities_df.groupby(["city"]).sum()["fare"]
suburban_ride_total_fare = suburban_cities_df.groupby(["city"]).sum()["fare"]

# %%
urban_avg_ride_fare = urban_ride_total / urban_ride_total_fare
suburban_avg_ride_fare = suburban_ride_total / suburban_ride_total_fare
rural_avg_ride_fare = rural_ride_total / rural_ride_total_fare

suburban_avg_ride_fare
# Out:
# city
# Barronchester         1.224736e+11
# Bethanyland           1.772827e+11
# Brandonfort           1.532151e+11
# Colemanland           1.668811e+11
# Davidfurt             1.429888e+11
# East Aaronbury        2.463061e+11
# East Danielview       1.218425e+11
# East Kentstad         1.503089e+11
# East Marymouth        1.929637e+11
# Grayville             2.039124e+11
# Josephside            1.363276e+11
# Lake Ann              1.324103e+11
# Lake Omar             1.967122e+11
# Lake Robertside       1.605124e+11
# Lake Scott            1.664717e+11
# Lewishaven            2.126167e+11
# Lewisland             1.744813e+11
# Mezachester           1.986347e+11
# Myersshire            1.245302e+11
# New Olivia            1.504507e+11
# New Raymond           1.850947e+11
# New Shannonberg       1.792720e+11
# Nicolechester         1.324782e+11
# North Jeffrey         1.963464e+11
# North Richardhaven    1.444763e+11
# North Timothy         1.425357e+11
# Port Shane            1.366181e+11
# Rodriguezview         1.266177e+11
# Sotoville             1.809786e+11
# South Brenda          1.310959e+11
# South Teresa          1.768873e+11
# Veronicaberg          1.560931e+11
# Victoriaport          1.754995e+11
# West Hannah           1.560574e+11
# West Kimmouth         1.662318e+11
# Williamsonville       1.593710e+11
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
urban_avg_driver_fare = urban_driver_total / urban_driver_total_fare
suburban_avg_driver_fare = suburban_driver_total / suburban_driver_total_fare
rural_avg_driver_fare = rural_driver_total / rural_driver_total_fare

urban_avg_driver_fare
# Out:
# city
# Amandaburgh            0.486980
# Barajasview            1.026359
# Carriemouth            1.836518
# Christopherfurt        1.673343
# Deanville              1.896092
#                          ...
# West Patrickchester    0.885485
# West Robert            1.552309
# West Samuelburgh       3.353608
# Williamsstad           2.421787
# Williamsview           1.729388
# Length: 66, dtype: float64

# %%
# Get the sum of the rides for each city type.
sum_rides_by_type = pyber_data_df.groupby(["type"])["ride_id"].count()
sum_rides_by_type
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
#get the number of total drivers by type
sum_drivers_by_type = city_data_df.groupby(["type"]).sum()["driver_count"]
sum_drivers_by_type
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#get the number of total fares by type
sum_fares_by_type = pyber_data_df.groupby(["type"])["fare"].sum()
sum_fares_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#get the average fares per ride and fares per driver.
average_ride_fare = sum_fares_by_type / sum_rides_by_type
average_driver_fare = sum_fares_by_type / sum_drivers_by_type
average_driver_fare
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 

pyber_summary_df = pd.DataFrame({
        "Total Rides": sum_rides_by_type,
        "Total Drivers": sum_drivers_by_type,
        "Total Fares": sum_fares_by_type,
        "Average Fare per Ride": average_ride_fare,
        "Average Fare per Driver": average_driver_fare})
       
pyber_summary_df.head()
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

pyber_summary_df.head()
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)

pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)

pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)

pyber_summary_df.head()
# Out:
#           Total Rides  Total Drivers Total Fares Average Fare per Ride  \
# Rural             125             78   $4,327.93                $34.62
# Suburban          625            490  $19,356.33                $30.97
# Urban            1625           2405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %%
## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head(10)
# Out:
#                  city           date   fare       ride_id  driver_count   type
# 0  Lake Jonathanshire  1/14/19 10:14  13.83  5.739410e+12             5  Urban
# 1  South Michelleport   3/4/19 18:24  30.24  2.343910e+12            72  Urban
# 2  Port Samanthamouth   2/24/19 4:29  33.44  2.005070e+12            57  Urban
# 3          Rodneyfort  2/10/19 23:22  23.44  5.149250e+12            34  Urban
# 4          South Jack    3/6/19 4:28  34.58  3.908450e+12            46  Urban
# 5        South Latoya  3/11/19 12:26   9.52  1.995000e+12            10  Urban
# 6       New Paulville  2/27/19 11:17  43.25  7.932080e+11            44  Urban
# 7        Simpsonburgh   4/26/19 0:43  35.98  1.119540e+11            21  Urban
# 8     South Karenland    1/8/19 3:28  35.09  7.995620e+12             4  Urban
# 9       North Jasmine    3/9/19 6:26  42.81  5.327640e+12            33  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
sum_date_fares_df = pyber_data_df.groupby(["date"])["fare"].sum()
sum_date_fares_df

# Get the average fare per ride for each date type.

urban_date_fare = urban_cities_df.groupby(["date"]).sum()["fare"]
rural_date_fare = rural_cities_df.groupby(["date"]).sum()["fare"]
suburban_date_fare = suburban_cities_df.groupby(["date"]).sum()["fare"]

# %%
pyber_date_summary_df = pd.DataFrame({
        "Rural": rural_date_fare,
        "Suburban": suburban_date_fare,
        "Urban": urban_date_fare})

pyber_date_summary_df.index.name = "date"
pyber_date_summary_df.columns.name = "type"

pyber_date_summary_df.head(10)
# Out:
# type          Rural  Suburban  Urban
# date
# 1/1/19 0:08     NaN       NaN  37.91
# 1/1/19 0:46     NaN     47.74    NaN
# 1/1/19 12:32    NaN     25.56    NaN
# 1/1/19 14:40    NaN       NaN   5.42
# 1/1/19 14:42    NaN       NaN  12.31
# 1/1/19 14:52    NaN     31.15    NaN
# 1/1/19 17:22    NaN       NaN  42.11
# 1/1/19 21:04    NaN       NaN  11.71
# 1/1/19 2:07     NaN     24.07    NaN
# 1/1/19 3:46     NaN       NaN   7.57

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
city_date_fare = pyber_data_df.groupby(["type","date"]).sum()[["fare"]]
city_date_fare.head(10)
# Out:
#                       fare
# type  date
# Rural 1/1/19 9:45    43.69
#       1/11/19 4:39   16.42
#       1/14/19 15:58  54.10
#       1/14/19 7:09   18.05
#       1/15/19 21:44  30.26
#       1/18/19 0:46   15.12
#       1/18/19 7:36   43.57
#       1/19/19 11:40  49.44
#       1/19/19 12:38  38.68
#       1/19/19 20:21  56.78

# %%
# df = df.reset_index()
city_date_fare = city_date_fare.reset_index()
city_date_fare.head()
# Out:
#     type           date   fare
# 0  Rural    1/1/19 9:45  43.69
# 1  Rural   1/11/19 4:39  16.42
# 2  Rural  1/14/19 15:58  54.10
# 3  Rural   1/14/19 7:09  18.05
# 4  Rural  1/15/19 21:44  30.26

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
city_date_fare_pivot = city_date_fare.pivot(index= "date", columns= "type", values= "fare")
city_date_fare_pivot.tail(10)
# Out:
# type          Rural  Suburban  Urban
# date
# 5/7/19 5:55     NaN       NaN   6.89
# 5/7/19 7:08     NaN     20.52    NaN
# 5/7/19 8:47     NaN       NaN  25.83
# 5/8/19 11:38    NaN       NaN  19.77
# 5/8/19 13:10    NaN       NaN  18.04
# 5/8/19 1:54     NaN       NaN  32.69
# 5/8/19 2:31     NaN       NaN  41.33
# 5/8/19 4:20     NaN       NaN  21.99
# 5/8/19 4:39     NaN       NaN  18.45
# 5/8/19 7:29     NaN       NaN  18.55

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
pivot_city_date_fare_total = city_date_fare_pivot.loc["1/1/2019":"4/29/2019"]
pivot_city_date_fare_total.head()
# Out:
# type           Rural  Suburban  Urban
# date
# 1/10/19 0:17     NaN     47.52    NaN
# 1/10/19 11:08    NaN     37.96    NaN
# 1/10/19 11:10    NaN     40.20    NaN
# 1/10/19 11:15    NaN     24.65    NaN
# 1/10/19 12:17    NaN       NaN  12.74

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
pivot_city_date_fare_total.index = pd.to_datetime(pivot_city_date_fare_total.index)
pivot_city_date_fare_total.tail()
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-04-29 06:08:00    NaN     17.99    NaN
# 2019-04-29 06:57:00    NaN       NaN  23.99
# 2019-04-29 07:09:00    NaN     34.77    NaN
# 2019-04-29 07:38:00    NaN       NaN   9.08
# 2019-04-29 07:50:00    NaN       NaN  17.89

# %%
# 7. Check that the datatype for the index is datetime using df.info()
pivot_city_date_fare_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2067 entries, 2019-01-10 00:17:00 to 2019-04-29 07:50:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     106 non-null    float64
#  1   Suburban  540 non-null    float64
#  2   Urban     1423 non-null   float64
# dtypes: float64(3)
# memory usage: 64.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
pivot_city_date_fare_total_weekly = pivot_city_date_fare_total.resample('W').sum()
pivot_city_date_fare_total_weekly.tail()
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-04-07  177.65    354.49   613.93
# 2019-04-14  214.60    568.47  2024.25
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29
# 2019-05-05   67.60    167.92   342.63

# %%
pivot_city_date_fare_total_line = pivot_city_date_fare_total_weekly.loc["1/1/2019":"4/29/2019"]
pivot_city_date_fare_total_line.tail(10)
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  177.65    354.49   613.93
# 2019-04-14  214.60    568.47  2024.25
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function.


# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
ax.plot = pivot_city_date_fare_total_line.plot(figsize=(20,7.5))
ax.plot.set_ylabel('Fare ($USD)',fontsize=14)
ax.plot.set_xlabel('Date',fontsize=14)
ax.plot.set_title("Total Fare by City Type", fontsize=20)
ax.set_yticks(np.arange(0, 2500, step=5.0))

lgnd = plt.legend(fontsize="12",mode="Expanded", loc="center", title="City Type")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
lgnd.get_title().set_fontsize(12)

# Save the figure.
plt.savefig("analysis/PyBer_fare_summary.png")

plt.show()

# %%
pivot_city_date_fare_total.describe()
# Out:
# type        Rural    Suburban        Urban
# count  106.000000  540.000000  1423.000000
# mean    33.573774   31.574352    24.716367
# std     14.662329   10.799268    11.991864
# min     10.110000   12.050000     4.050000
# 25%     19.477500   22.807500    14.545000
# 50%     34.370000   31.505000    24.860000
# 75%     45.530000   40.425000    34.880000
# max     58.550000   68.610000    66.700000
